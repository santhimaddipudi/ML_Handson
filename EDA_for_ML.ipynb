# %% [markdown]
# <a href="https://colab.research.google.com/github/santhimaddipudi/ML_Handson/blob/main/EDA_for_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing, model_selection

# %%
# For CSV
data = pd.read_csv("/content/sample_data/forbes.csv")

# %%
data.head()
# Out:
#    Rank                  Company        Country  Sales  Profits  Assets  \
# 0     1                     ICBC          China  151.4     42.0  3473.2
# 1     2  China Construction Bank          China  134.2     35.0  3016.6
# 2     3       Berkshire Hathaway  United States  222.9     24.1   620.9
# 3     4           JPMorgan Chase  United States  102.5     24.2  2513.0
# 4     5              Wells Fargo  United States   97.6     21.9  1943.4
#
#    Market Value      Sector             Industry
# 0         229.8  Financials          Major Banks
# 1         200.5  Financials       Regional Banks
# 2         409.9  Financials  Investment Services
# 3         306.6  Financials          Major Banks
# 4         274.4  Financials          Major Banks

# %%
data.tail()
# Out:
#       Rank              Company        Country  Sales  Profits  Assets  \
# 1995  1996            BEKB-BCBE    Switzerland  0.555    0.131    27.9
# 1996  1997    Fastighets Balder         Sweden  0.630    0.639    10.2
# 1997  1998  Akamai Technologies  United States  2.300    0.316     4.4
# 1998  1999            Oita Bank          Japan  0.523    0.071    27.9
# 1999  2000        Tech Mahindra          India  4.200    0.469     3.6
#
#       Market Value                  Sector           Industry
# 1995         1.700              Financials     Regional Banks
# 1996         3.800               Materials                NaN
# 1997        10.100  Information Technology  Computer Services
# 1998         0.595              Financials     Regional Banks
# 1999         6.700  Information Technology                NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tickers  5 non-null      object
#  1   eps      5 non-null      object
#  2   revenue  5 non-null      int64
#  3   price    5 non-null      object
#  4   people   5 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 328.0+ bytes

# %%
data.shape  # Returns (number_of_rows, number_of_columns)
# Out:
# (2000, 9)

# %%
data.describe()
# Out:
#               Rank        Sales      Profits       Assets  Market Value
# count  2000.000000  2000.000000  2000.000000  2000.000000   2000.000000
# mean   1000.500000    17.664510     1.240713    84.533546     24.417844
# std     577.494589    29.320116     2.918742   260.984489     44.761400
# min       1.000000     0.001000   -13.000000     0.001000      0.072000
# 25%     500.750000     4.000000     0.318000    10.875000      6.600000
# 50%    1000.500000     8.800000     0.613000    22.900000     11.950000
# 75%    1500.250000    17.425000     1.300000    52.400000     24.400000
# max    2000.000000   485.300000    45.200000  3473.200000    752.000000

# %% [markdown]
# ##Duplication and Missing Values Management

# %%
# Get duplicates
duplicates = data.duplicated()
duplicates
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Length: 2000, dtype: bool

# %%
#Remove Duplicates
data = data.drop_duplicates()

# %%
missing_values = data.isnull().sum()
missing_values
# Out:
# Rank              0
# Company           0
# Country           0
# Sales             0
# Profits           0
# Assets            0
# Market Value      0
# Sector          197
# Industry        491
# dtype: int64

# %%
# Filling missing values with the mean
data['Profits'] = data['Profits'].fillna(data['Profits'].mean())

# %%
# Dropping rows with missing values
data = data.dropna()

# %%
data.head()
# Out:
#    Rank                  Company        Country  Sales  Profits  Assets  \
# 0     1                     ICBC          China  151.4     42.0  3473.2
# 1     2  China Construction Bank          China  134.2     35.0  3016.6
# 2     3       Berkshire Hathaway  United States  222.9     24.1   620.9
# 3     4           JPMorgan Chase  United States  102.5     24.2  2513.0
# 4     5              Wells Fargo  United States   97.6     21.9  1943.4
#
#    Market Value      Sector             Industry
# 0         229.8  Financials          Major Banks
# 1         200.5  Financials       Regional Banks
# 2         409.9  Financials  Investment Services
# 3         306.6  Financials          Major Banks
# 4         274.4  Financials          Major Banks

# %% [markdown]
# ##Data Reduction

# %%
#DROP irrelevant columns
data = data.drop(['irrelevant_column1', 'irrelevant_column2'], axis=1)
#Remove columns with constant values as they don’t add any information.
data = data.loc[:, data.apply(pd.Series.nunique) != 1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-868ec14a6bba> in <cell line: 2>()
#       1 #DROP irrelevant columns
# ----> 2 data = data.drop(['irrelevant_column1', 'irrelevant_column2'], axis=1)
#       3 #Remove columns with constant values as they don’t add any information.
#       4 data = data.loc[:, data.apply(pd.Series.nunique) != 1]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
#    4551         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4589                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4590             else:
# -> 4591                 new_axis = axis.drop(labels, errors=errors)
#    4592             indexer = axis.get_indexer(new_axis)
#    4593
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6697         if mask.any():
#    6698             if errors != "ignore":
# -> 6699                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700             indexer = indexer[~mask]
#    6701         return self.delete(indexer)
#
# KeyError: "['irrelevant_column1', 'irrelevant_column2'] not found in axis"

# %% [markdown]
# ##Feature Engineering:Feature Engineering is the process of using domain knowledge to create new features from the raw data, which can significantly improve the performance of machine learning models.

# %%
# Example: Creating a feature for the age of a car from the 'Year' column
#data['Car_Age'] = current_year - data['Year']

# Example: Binning ages into groups
data['Profits_group'] = pd.cut(data['Profits'], bins=[0, 30,60,100], labels=['low', 'min',  'high'])

# Example: Extracting a brand name from a product description
data['Industry_catgory'] = data['Industry'].apply(lambda x: x.split()[0])

# %%
data
# Out:
#       Rank                  Company        Country    Sales  Profits  Assets  \
# 0        1                     ICBC          China  151.400   42.000  3473.2
# 1        2  China Construction Bank          China  134.200   35.000  3016.6
# 2        3       Berkshire Hathaway  United States  222.900   24.100   620.9
# 3        4           JPMorgan Chase  United States  102.500   24.200  2513.0
# 4        5              Wells Fargo  United States   97.600   21.900  1943.4
# ...    ...                      ...            ...      ...      ...     ...
# 1993  1994    Shaanxi Coal Industry          China    3.800   -0.024    13.6
# 1994  1995                  Aurubis        Germany   10.600    0.249     4.5
# 1995  1996                BEKB-BCBE    Switzerland    0.555    0.131    27.9
# 1997  1998      Akamai Technologies  United States    2.300    0.316     4.4
# 1998  1999                Oita Bank          Japan    0.523    0.071    27.9
#
#       Market Value                  Sector                     Industry  \
# 0          229.800              Financials                  Major Banks
# 1          200.500              Financials               Regional Banks
# 2          409.900              Financials          Investment Services
# 3          306.600              Financials                  Major Banks
# 4          274.400              Financials                  Major Banks
# ...            ...                     ...                          ...
# 1993         9.000               Materials  Diversified Metals & Mining
# 1994         3.100               Materials  Diversified Metals & Mining
# 1995         1.700              Financials               Regional Banks
# 1997        10.100  Information Technology            Computer Services
# 1998         0.595              Financials               Regional Banks
#
#      Profits_group Industry_catgory
# 0              min            Major
# 1              min         Regional
# 2              low       Investment
# 3              low            Major
# 4              low            Major
# ...            ...              ...
# 1993           NaN      Diversified
# 1994           low      Diversified
# 1995           low         Regional
# 1997           low         Computer
# 1998           low         Regional
#
# [1508 rows x 11 columns]

# %% [markdown]
# ##Creating Features
